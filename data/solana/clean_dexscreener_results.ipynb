# %% [markdown]
# # EDA on Dexscreener Results
# This notebook loads `solana_dexscreener_info.json` and provides a starting point for exploratory data analysis (EDA).

# %%
import json
import pandas as pd
from pandas import json_normalize

# Load the results
with open('solana_dexscreener_info.json', 'r') as f:
    data = json.load(f)

# Convert to DataFrame
df = pd.DataFrame(data)
print(f'Loaded {len(df)} records.')
df.head()
# Out:
# Loaded 5961 records.
#                                    mint_address          usd_volume  \
# 0   So11111111111111111111111111111111111111112    834366153878.362
# 1  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v   326903656510.9317
# 2  3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh  222885529101.90427
# 3  Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB  55122557274.568504
# 4  DL8CcQBJT95hSyzJZE6x3PyafzjH2Xu8E1BdN7eWzwqF   48807687744.86127
#
#                                     dexscreener_data
# 0  {"schemaVersion":"1.0.0","pairs":[{"chainId":"...
# 1  {"schemaVersion":"1.0.0","pairs":[{"chainId":"...
# 2  {"schemaVersion":"1.0.0","pairs":[{"chainId":"...
# 3  {"schemaVersion":"1.0.0","pairs":[{"chainId":"...
# 4             {"schemaVersion":"1.0.0","pairs":null}

# %%
# Parse the dexscreener_data JSON string for the first row as an example
sample_json = df.loc[1, 'dexscreener_data']
try:
    parsed = json.loads(sample_json)
    print("Successfully parsed JSON")
except Exception as e:
    print('Error parsing JSON:', e)
    parsed = {}
parsed
# Out:
# Successfully parsed JSON
# {'schemaVersion': '1.0.0',
#  'pairs': [{'chainId': 'solana',
#    'dexId': 'orca',
#    'url': 'https://dexscreener.com/solana/4fuuiyxtq6qcrdsq9oubyctm7bqswytsyluegzlty4t4',
#    'pairAddress': '4fuUiYxTQ6QCrdSq9ouBYcTM7bqSwYTSyLueGZLTy4T4',
#    'labels': ['wp'],
#    'baseToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'quoteToken': {'address': 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB',
#     'name': 'USDT',
#     'symbol': 'USDT'},
#    'priceNative': '0.9995',
#    'priceUsd': '0.9995',
#    'txns': {'m5': {'buys': 0, 'sells': 2},
#     'h1': {'buys': 36, 'sells': 31},
#     'h6': {'buys': 593, 'sells': 154},
#     'h24': {'buys': 1332, 'sells': 425}},
#    'volume': {'h24': 641456.21, 'h6': 303432.67, 'h1': 16898.21, 'm5': 24.02},
#    'priceChange': {'h1': -0.02, 'h6': -0.02, 'h24': -0.01},
#    'liquidity': {'usd': 2054254.9, 'base': 1051608, 'quote': 1003163},
#    'fdv': 9338306228,
#    'marketCap': 61027113944,
#    'pairCreatedAt': 1669603219000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v.png?key=da8880',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v/header.png?key=da8880',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v?timestamp=1750018500000',
#     'websites': [],
#     'socials': []}},
#   {'chainId': 'solana',
#    'dexId': 'raydium',
#    'url': 'https://dexscreener.com/solana/bztgqeys6exuxicyphecyq7pybqodxqmvkjubp4r8muu',
#    'pairAddress': 'BZtgQEyS6eXUXicYPHecYQ7PybqodXQMvkjUbP4R8mUU',
#    'labels': ['CLMM'],
#    'baseToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'quoteToken': {'address': 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB',
#     'name': 'USDT',
#     'symbol': 'USDT'},
#    'priceNative': '0.9996',
#    'priceUsd': '0.9996',
#    'txns': {'m5': {'buys': 1, 'sells': 0},
#     'h1': {'buys': 27, 'sells': 10},
#     'h6': {'buys': 821, 'sells': 69},
#     'h24': {'buys': 1548, 'sells': 365}},
#    'volume': {'h24': 1508232.06, 'h6': 685105.33, 'h1': 11865.49, 'm5': 200},
#    'priceChange': {'h24': 0.01},
#    'liquidity': {'usd': 7788188.56, 'base': 5886520, 'quote': 1903971},
#    'fdv': 9339242345,
#    'marketCap': 61033231593,
#    'pairCreatedAt': 1723699296000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v.png?key=da8880',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v/header.png?key=da8880',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v?timestamp=1750018500000',
#     'websites': [],
#     'socials': []}},
#   {'chainId': 'solana',
#    'dexId': 'meteora',
#    'url': 'https://dexscreener.com/solana/arwi1s4daitg5dx7s4m4zsrxqpmd1mrtmbu9ue2tpmeq',
#    'pairAddress': 'ARwi1S4DaiTG5DX7S4M4ZsrXqpMD1MrTmbu9ue2tpmEq',
#    'labels': ['DLMM'],
#    'baseToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'quoteToken': {'address': 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB',
#     'name': 'USDT',
#     'symbol': 'USDT'},
#    'priceNative': '0.9994',
#    'priceUsd': '0.9994',
#    'txns': {'m5': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 9, 'sells': 16},
#     'h6': {'buys': 302, 'sells': 48},
#     'h24': {'buys': 398, 'sells': 206}},
#    'volume': {'h24': 844763.04, 'h6': 71697.89, 'h1': 1334.23, 'm5': 0},
#    'priceChange': {'h1': -0.01, 'h6': -0.02, 'h24': -0.01},
#    'liquidity': {'usd': 3906965.08, 'base': 2759574, 'quote': 1148774},
#    'fdv': 9338211876,
#    'marketCap': 61026497341,
#    'pairCreatedAt': 1706214035000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v.png?key=da8880',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v/header.png?key=da8880',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v?timestamp=1750018500000',
#     'websites': [],
#     'socials': []}},
#   {'chainId': 'solana',
#    'dexId': 'meteora',
#    'url': 'https://dexscreener.com/solana/32d4zrxnc1essbjievhfphzm3rh6czfuprwuuwxd9prg',
#    'pairAddress': '32D4zRxNc1EssbJieVHfPhZM3rH6CzfUPrWUuWxD9prG',
#    'labels': ['DYN'],
#    'baseToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'quoteToken': {'address': 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB',
#     'name': 'USDT',
#     'symbol': 'USDT'},
#    'priceNative': '0.9995',
#    'priceUsd': '0.9995',
#    'txns': {'m5': {'buys': 0, 'sells': 1},
#     'h1': {'buys': 0, 'sells': 8},
#     'h6': {'buys': 343, 'sells': 23},
#     'h24': {'buys': 520, 'sells': 47}},
#    'volume': {'h24': 252727.69, 'h6': 183283.19, 'h1': 166.22, 'm5': 0.95},
#    'priceChange': {'h6': -0.01, 'h24': 0.01},
#    'liquidity': {'usd': 8497913.3, 'base': 6768068, 'quote': 1732900},
#    'fdv': 8612517834,
#    'marketCap': 61029553258,
#    'pairCreatedAt': 1703167204000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v.png?key=da8880',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v/header.png?key=da8880',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v?timestamp=1750018500000',
#     'websites': [],
#     'socials': []}},
#   {'chainId': 'solana',
#    'dexId': 'orca',
#    'url': 'https://dexscreener.com/solana/f13xvvx45jvgd84ynk3c8t89uejqvxjcltmhfpmaxahp',
#    'pairAddress': 'F13xvvx45jVGd84ynK3c8T89UejQVxjCLtmHfPmAXAHP',
#    'labels': ['v2'],
#    'baseToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'quoteToken': {'address': 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB',
#     'name': 'USDT',
#     'symbol': 'USDT'},
#    'priceNative': '0.9984',
#    'priceUsd': '0.9984',
#    'txns': {'m5': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 0, 'sells': 0},
#     'h6': {'buys': 0, 'sells': 2},
#     'h24': {'buys': 2, 'sells': 2}},
#    'volume': {'h24': 144.46, 'h6': 2.75, 'h1': 0, 'm5': 0},
#    'priceChange': {'h6': -0.14, 'h24': -0.14},
#    'liquidity': {'usd': 153051.42, 'base': 79682, 'quote': 73488},
#    'fdv': 9328863383,
#    'marketCap': 60965403656,
#    'pairCreatedAt': 1669604057000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v.png?key=da8880',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v/header.png?key=da8880',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v?timestamp=1750018500000',
#     'websites': [],
#     'socials': []}},
#   {'chainId': 'solana',
#    'dexId': 'raydium',
#    'url': 'https://dexscreener.com/solana/3neugardmfgnktkjlquceuncfknfccgsffmjctx6bagx',
#    'pairAddress': '3NeUgARDmFgnKtkJLqUcEUNCfknFCcGsFfMJCtx6bAgx',
#    'labels': ['CLMM'],
#    'baseToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'quoteToken': {'address': 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB',
#     'name': 'USDT',
#     'symbol': 'USDT'},
#    'priceNative': '0.9996',
#    'priceUsd': '0.9996',
#    'txns': {'m5': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 0, 'sells': 3},
#     'h6': {'buys': 94, 'sells': 47},
#     'h24': {'buys': 201, 'sells': 107}},
#    'volume': {'h24': 13670.74, 'h6': 8265.31, 'h1': 114.58, 'm5': 0},
#    'priceChange': {'h24': 0.01},
#    'liquidity': {'usd': 72211.35, 'base': 43652, 'quote': 28575},
#    'fdv': 9339264626,
#    'marketCap': 61033377207,
#    'pairCreatedAt': 1723699419000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v.png?key=da8880',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v/header.png?key=da8880',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v?timestamp=1750018500000',
#     'websites': [],
#     'socials': []}},
#   {'chainId': 'solana',
#    'dexId': 'orca',
#    'url': 'https://dexscreener.com/solana/fpphjpjbk98pd5z3xxqudcrzdudqfracrju8yvdt1zkr',
#    'pairAddress': 'FPPHjpjBk98pd5Z3xXQuDcrZdUdqfraCRJU8yvdT1ZKR',
#    'labels': ['wp'],
#    'baseToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'quoteToken': {'address': 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB',
#     'name': 'USDT',
#     'symbol': 'USDT'},
#    'priceNative': '0.9998',
#    'priceUsd': '0.9998',
#    'txns': {'m5': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 3, 'sells': 0},
#     'h6': {'buys': 16, 'sells': 16},
#     'h24': {'buys': 44, 'sells': 23}},
#    'volume': {'h24': 1196.98, 'h6': 575.92, 'h1': 9.34, 'm5': 0},
#    'priceChange': {'h6': 0.01, 'h24': 0.06},
#    'liquidity': {'usd': 16597.42, 'base': 10197, 'quote': 6401.3309},
#    'fdv': 9341498002,
#    'marketCap': 61047972625,
#    'pairCreatedAt': 1703788397000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v.png?key=da8880',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v/header.png?key=da8880',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v?timestamp=1750018500000',
#     'websites': [],
#     'socials': []}},
#   {'chainId': 'solana',
#    'dexId': 'meteora',
#    'url': 'https://dexscreener.com/solana/4bg8udlxem4t6pcyow7iuizaz9hmoxhtatmqusxigfzu',
#    'pairAddress': '4bg8UDLXEm4T6pCyoW7iUizAz9HMoxhTAtMquSXigFZu',
#    'labels': ['DLMM'],
#    'baseToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'quoteToken': {'address': 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB',
#     'name': 'USDT',
#     'symbol': 'USDT'},
#    'priceNative': '0.9993',
#    'priceUsd': '0.9993',
#    'txns': {'m5': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 0, 'sells': 0},
#     'h6': {'buys': 0, 'sells': 1},
#     'h24': {'buys': 17, 'sells': 12}},
#    'volume': {'h24': 128.06, 'h6': 0.03, 'h1': 0, 'm5': 0},
#    'priceChange': {'h6': -0.05, 'h24': -0.02},
#    'liquidity': {'usd': 5147.73, 'base': 2452.8943, 'quote': 2696.34},
#    'fdv': 9337194330,
#    'marketCap': 61019847534,
#    'pairCreatedAt': 1715973763000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v.png?key=da8880',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v/header.png?key=da8880',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v?timestamp=1750018500000',
#     'websites': [],
#     'socials': []}},
#   {'chainId': 'solana',
#    'dexId': 'orca',
#    'url': 'https://dexscreener.com/solana/elqxddrqcnrjxqnqzdpwbxeebpq6sebcqrbe12wphbu',
#    'pairAddress': 'ELqXddRqcnRJXQnqZdPwBXEEBpQ6SEbCQrBe12wpHBU',
#    'labels': ['wp'],
#    'baseToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'quoteToken': {'address': 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB',
#     'name': 'USDT',
#     'symbol': 'USDT'},
#    'priceNative': '1.000004656',
#    'priceUsd': '1.0000046',
#    'txns': {'m5': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 0, 'sells': 0},
#     'h6': {'buys': 0, 'sells': 0},
#     'h24': {'buys': 2, 'sells': 0}},
#    'volume': {'h24': 3.17, 'h6': 0, 'h1': 0, 'm5': 0},
#    'priceChange': {},
#    'liquidity': {'usd': 5400.21, 'base': 5118.4988, 'quote': 281.6894},
#    'fdv': 9342941826,
#    'marketCap': 61057408213,
#    'pairCreatedAt': 1709683865000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v.png?key=da8880',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v/header.png?key=da8880',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v?timestamp=1750018500000',
#     'websites': [],
#     'socials': []}},
#   {'chainId': 'solana',
#    'dexId': 'meteora',
#    'url': 'https://dexscreener.com/solana/ugv7hfb1ckuxoab36g65bzk8uvorpar7sfrkwdzrzdj',
#    'pairAddress': 'uGv7HFB1cKuxoAb36g65BzK8UVorpAR7SfrkwDZRzdJ',
#    'labels': ['DLMM'],
#    'baseToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'quoteToken': {'address': 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB',
#     'name': 'USDT',
#     'symbol': 'USDT'},
#    'priceNative': '0.9998',
#    'priceUsd': '0.9998',
#    'txns': {'m5': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 1, 'sells': 0},
#     'h6': {'buys': 1, 'sells': 0},
#     'h24': {'buys': 1, 'sells': 1}},
#    'volume': {'h24': 5.14, 'h6': 5, 'h1': 5, 'm5': 0},
#    'priceChange': {'h1': 0.04, 'h6': 0.04, 'h24': 0.04},
#    'liquidity': {'usd': 2247.65, 'base': 1244.5255, 'quote': 1003.3753},
#    'fdv': 9341031982,
#    'marketCap': 61044927117,
#    'pairCreatedAt': 1712653306000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v.png?key=da8880',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v/header.png?key=da8880',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v?timestamp=1750018500000',
#     'websites': [],
#     'socials': []}},
#   {'chainId': 'solana',
#    'dexId': 'meteora',
#    'url': 'https://dexscreener.com/solana/4wqg97j5vqbtgjxvk5ivofjsofgoa36ggunqsbyqhbe7',
#    'pairAddress': '4wqG97j5vQBtGjxvK5ivoFJSofgoa36gGuNQsbyQHBE7',
#    'labels': ['DLMM'],
#    'baseToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'quoteToken': {'address': 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB',
#     'name': 'USDT',
#     'symbol': 'USDT'},
#    'priceNative': '0.9991',
#    'priceUsd': '0.9991',
#    'txns': {'m5': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 0, 'sells': 0},
#     'h6': {'buys': 0, 'sells': 2},
#     'h24': {'buys': 1, 'sells': 2}},
#    'volume': {'h24': 0.16, 'h6': 0, 'h1': 0, 'm5': 0},
#    'priceChange': {'h6': -0.07, 'h24': -0.07},
#    'liquidity': {'usd': 2071.66, 'base': 1200.4391, 'quote': 872.2697},
#    'fdv': 9334738583,
#    'marketCap': 61003798895,
#    'pairCreatedAt': 1712012277000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v.png?key=da8880',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v/header.png?key=da8880',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v?timestamp=1750018500000',
#     'websites': [],
#     'socials': []}},
#   {'chainId': 'solana',
#    'dexId': 'meteora',
#    'url': 'https://dexscreener.com/solana/5u2vwpax136m5kmbentfbebml77sosnfdbqbznrxm76f',
#    'pairAddress': '5u2VwpaX136M5kmBEnTFbEbmL77sosNfDBQBZNRxM76F',
#    'labels': ['DLMM'],
#    'baseToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'quoteToken': {'address': 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB',
#     'name': 'USDT',
#     'symbol': 'USDT'},
#    'priceNative': '0.9998',
#    'priceUsd': '0.9998',
#    'txns': {'m5': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 3, 'sells': 0},
#     'h6': {'buys': 7, 'sells': 0},
#     'h24': {'buys': 9, 'sells': 0}},
#    'volume': {'h24': 25.49, 'h6': 23.35, 'h1': 1.05, 'm5': 0},
#    'priceChange': {'h1': 0.02, 'h6': 0.02, 'h24': 0.02},
#    'liquidity': {'usd': 1774.03, 'base': 1408.6851, 'quote': 365.4981},
#    'fdv': 9341928025,
#    'marketCap': 61050782879,
#    'pairCreatedAt': 1716224555000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v.png?key=da8880',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v/header.png?key=da8880',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v?timestamp=1750018500000',
#     'websites': [],
#     'socials': []}},
#   {'chainId': 'solana',
#    'dexId': 'orca',
#    'url': 'https://dexscreener.com/solana/cxf3jkhgrauhqjfk8l5xukltjmelfqhuyhlcyysautmc',
#    'pairAddress': 'CxF3jKhGrauHQjFk8L5XUkLTjmeLFqHUYHLCYYSautMC',
#    'labels': ['wp'],
#    'baseToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'quoteToken': {'address': 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB',
#     'name': 'USDT',
#     'symbol': 'USDT'},
#    'priceNative': '0.9999',
#    'priceUsd': '0.9999',
#    'txns': {'m5': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 0, 'sells': 0},
#     'h6': {'buys': 5, 'sells': 0},
#     'h24': {'buys': 5, 'sells': 0}},
#    'volume': {'h24': 2.85, 'h6': 2.85, 'h1': 0, 'm5': 0},
#    'priceChange': {},
#    'liquidity': {'usd': 702.24, 'base': 475.0114, 'quote': 227.2649},
#    'fdv': 9342302740,
#    'marketCap': 61053231699,
#    'pairCreatedAt': 1674184768000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v.png?key=da8880',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v/header.png?key=da8880',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v?timestamp=1750018500000',
#     'websites': [],
#     'socials': []}},
#   {'chainId': 'solana',
#    'dexId': 'meteora',
#    'url': 'https://dexscreener.com/solana/9d9mb8kooffad3sctgztkxqypkshx6ezhbkio89ixyy2',
#    'pairAddress': '9d9mb8kooFfaD3SctgZtkxQypkshx6ezhbKio89ixyy2',
#    'labels': ['DLMM'],
#    'baseToken': {'address': '6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN',
#     'name': 'OFFICIAL TRUMP',
#     'symbol': 'TRUMP'},
#    'quoteToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '9.9314',
#    'priceUsd': '9.93',
#    'txns': {'m5': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 3, 'sells': 16},
#     'h6': {'buys': 315, 'sells': 357},
#     'h24': {'buys': 1529, 'sells': 1325}},
#    'volume': {'h24': 30594612.44, 'h6': 4703384.98, 'h1': 338382.59, 'm5': 0},
#    'priceChange': {'h1': -0.95, 'h6': -0.75, 'h24': 0.04},
#    'liquidity': {'usd': 361967857.23, 'base': 11774874, 'quote': 245026672},
#    'fdv': 9931412386,
#    'marketCap': 1986283086,
#    'pairCreatedAt': 1737196771000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN.png?key=f90857',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN/header.png?key=f90857',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN?timestamp=1750018500000',
#     'websites': [{'label': 'Website',
#       'url': 'https://x.com/realDonaldTrump/status/1880446012168249386'}],
#     'socials': [{'type': 'twitter', 'url': 'https://x.com/GetTrumpMemes'}]}},
#   {'chainId': 'solana',
#    'dexId': 'orca',
#    'url': 'https://dexscreener.com/solana/3ndjn1njvukgrjbc1hhvper6kwtzkhdydrpycjyx3cxk',
#    'pairAddress': '3ndjN1nJVUKGrJBc1hhVpER6kWTZKHdyDrPyCJyX3CXK',
#    'labels': ['wp'],
#    'baseToken': {'address': 'KMNo3nJsBXfcpJTVhZcXLW7RmTwTt4GVFE7suUBo9sS',
#     'name': 'Kamino',
#     'symbol': 'KMNO'},
#    'quoteToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '0.06740',
#    'priceUsd': '0.06740',
#    'txns': {'m5': {'buys': 39, 'sells': 38},
#     'h1': {'buys': 807, 'sells': 775},
#     'h6': {'buys': 7918, 'sells': 8762},
#     'h24': {'buys': 19526, 'sells': 19915}},
#    'volume': {'h24': 7567939.49,
#     'h6': 3462761.5,
#     'h1': 294042.86,
#     'm5': 16792.82},
#    'priceChange': {'m5': 0.02, 'h1': -1.06, 'h6': 5.48, 'h24': 8.15},
#    'liquidity': {'usd': 3215206.44, 'base': 29756903, 'quote': 1209417},
#    'fdv': 674057374,
#    'marketCap': 140813551,
#    'pairCreatedAt': 1728555415000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/KMNo3nJsBXfcpJTVhZcXLW7RmTwTt4GVFE7suUBo9sS.png?key=8db26b',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/KMNo3nJsBXfcpJTVhZcXLW7RmTwTt4GVFE7suUBo9sS/header.png?key=8db26b',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/KMNo3nJsBXfcpJTVhZcXLW7RmTwTt4GVFE7suUBo9sS?timestamp=1750018500000',
#     'websites': [],
#     'socials': [{'type': 'twitter', 'url': 'https://x.com/KaminoFinance'}]}},
#   {'chainId': 'solana',
#    'dexId': 'raydium',
#    'url': 'https://dexscreener.com/solana/dkzxe2czabmm7rnyozqqc4nf3sg6jjgeybh4qcw48se6',
#    'pairAddress': 'DKZxE2cZaBmM7rNYozQQc4Nf3sG6jjgeyBH4QCw48se6',
#    'labels': ['CLMM'],
#    'baseToken': {'address': '85vdovHhkXnDi98EYMQmD2vXS82jRP1VDDXfkJ38pump',
#     'name': 'Just a peace guy',
#     'symbol': 'PEACEGUY'},
#    'quoteToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '0.0007820',
#    'priceUsd': '0.0007820',
#    'txns': {'m5': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 2, 'sells': 12},
#     'h6': {'buys': 207, 'sells': 235},
#     'h24': {'buys': 1660, 'sells': 1626}},
#    'volume': {'h24': 65090.75, 'h6': 7671.34, 'h1': 4.88, 'm5': 0},
#    'priceChange': {'h1': -19.83, 'h6': -58.95, 'h24': -75.22},
#    'liquidity': {'usd': 1985.75, 'base': 1913921, 'quote': 489.01317},
#    'fdv': 782030,
#    'marketCap': 782030,
#    'pairCreatedAt': 1749925953000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/85vdovHhkXnDi98EYMQmD2vXS82jRP1VDDXfkJ38pump.png?key=d0ff01',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/85vdovHhkXnDi98EYMQmD2vXS82jRP1VDDXfkJ38pump/header.png?key=d0ff01',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/85vdovHhkXnDi98EYMQmD2vXS82jRP1VDDXfkJ38pump?timestamp=1750018500000',
#     'websites': [{'label': 'Website', 'url': 'https://www.peaceguy.io/'}],
#     'socials': [{'type': 'twitter', 'url': 'https://x.com/Peaceguysol'},
#      {'type': 'tiktok', 'url': 'https://www.tiktok.com/@chillpeaceguy'}]},
#    'boosts': {'active': 50}},
#   {'chainId': 'solana',
#    'dexId': 'raydium',
#    'url': 'https://dexscreener.com/solana/gla61nxfqkfx2jd2gzl9xvsqwjwncfsgcxjdn5x4nfaq',
#    'pairAddress': 'GLA61nXFQKfX2jd2GzL9xVsqWJWNCfSgcxJdn5X4NfaQ',
#    'labels': ['CLMM'],
#    'baseToken': {'address': 'BrzVsxBs6wVSnVjQLbjRNjSVY2rACRWSocnHwcDciPFr',
#     'name': 'Polyhedra Network',
#     'symbol': 'ZKJ'},
#    'quoteToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '2.1809',
#    'priceUsd': '2.18',
#    'txns': {'m5': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 0, 'sells': 0},
#     'h6': {'buys': 3, 'sells': 1},
#     'h24': {'buys': 4, 'sells': 2}},
#    'volume': {'h24': 205.54, 'h6': 103.56, 'h1': 0, 'm5': 0},
#    'priceChange': {},
#    'liquidity': {'usd': 2179952056.45, 'base': 999538783, 'quote': 6002.323},
#    'fdv': 2180951945,
#    'marketCap': 2180951945,
#    'pairCreatedAt': 1747023366000},
#   {'chainId': 'solana',
#    'dexId': 'raydium',
#    'url': 'https://dexscreener.com/solana/8dppdvemt4gr7mu5paqkkxwuqdur6kdvvder4ewh4m8s',
#    'pairAddress': '8DPPdVemT4gR7MU5paqKkXWuqdUR6KDVvDEr4ewH4m8s',
#    'labels': ['CPMM'],
#    'baseToken': {'address': 'JCeoBX79HfatfaY6xvuNyCHf86hwgkCCWDpEycVHtime',
#     'name': "toly's minutes",
#     'symbol': 'toly'},
#    'quoteToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '32.1705',
#    'priceUsd': '32.17',
#    'txns': {'m5': {'buys': 1, 'sells': 0},
#     'h1': {'buys': 22, 'sells': 11},
#     'h6': {'buys': 316, 'sells': 288},
#     'h24': {'buys': 376, 'sells': 365}},
#    'volume': {'h24': 203251.31, 'h6': 166372.28, 'h1': 4673.44, 'm5': 454.77},
#    'priceChange': {'m5': 0.55, 'h1': -1.92, 'h6': 29.09, 'h24': 38.14},
#    'liquidity': {'usd': 331793.15, 'base': 5156.7906, 'quote': 165896},
#    'fdv': 3216870,
#    'marketCap': 3216870,
#    'pairCreatedAt': 1740455212000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/JCeoBX79HfatfaY6xvuNyCHf86hwgkCCWDpEycVHtime.png?key=c15a63',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/JCeoBX79HfatfaY6xvuNyCHf86hwgkCCWDpEycVHtime/header.png?key=c15a63',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/JCeoBX79HfatfaY6xvuNyCHf86hwgkCCWDpEycVHtime?timestamp=1750018500000',
#     'websites': [{'label': 'Website',
#       'url': 'https://time.fun/toly?tab=market'}],
#     'socials': [{'type': 'twitter', 'url': 'https://x.com/aeyakovenko'}]}},
#   {'chainId': 'solana',
#    'dexId': 'raydium',
#    'url': 'https://dexscreener.com/solana/3mjwoqzhaabcqlbsn6dtmgl6rpazvgyaxbyghaxiqytx',
#    'pairAddress': '3MjwoqZHAAbCQLBSn6DtmgL6rpazvgYaxBYGHaxiQYTx',
#    'labels': ['CLMM'],
#    'baseToken': {'address': '9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump',
#     'name': 'Fartcoin ',
#     'symbol': 'Fartcoin '},
#    'quoteToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '1.1950',
#    'priceUsd': '1.19',
#    'txns': {'m5': {'buys': 12, 'sells': 41},
#     'h1': {'buys': 479, 'sells': 635},
#     'h6': {'buys': 3438, 'sells': 3729},
#     'h24': {'buys': 11384, 'sells': 12117}},
#    'volume': {'h24': 5791530.31,
#     'h6': 1555946.91,
#     'h1': 237773.98,
#     'm5': 7366.48},
#    'priceChange': {'m5': -0.31, 'h1': -2.95, 'h6': -1.78, 'h24': 6.53},
#    'liquidity': {'usd': 279065.1, 'base': 127786, 'quote': 126352},
#    'fdv': 1195052668,
#    'marketCap': 1195049911,
#    'pairCreatedAt': 1739033064000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump.png?key=6a4a45',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump/header.png?key=6a4a45',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump?timestamp=1750018500000',
#     'websites': [{'label': 'Website',
#       'url': 'https://www.infinitebackrooms.com/dreams/conversation-1721540624-scenario-terminal-of-truths-txt'}],
#     'socials': [{'type': 'twitter', 'url': 'https://x.com/FartCoinOfSOL'}]}},
#   {'chainId': 'solana',
#    'dexId': 'orca',
#    'url': 'https://dexscreener.com/solana/agesxtvwwmojfwynrxknvp9cfuc5cq7m4rzmrselxfuj',
#    'pairAddress': 'AgeSxtVWWMojFWYNrXKnVp9cFuC5CQ7M4rzmrseLxfUj',
#    'labels': ['wp'],
#    'baseToken': {'address': 'J3NKxxXZcnNiMjKw9hYb2K4LUxgwB6t1FtPtQVsv3KFr',
#     'name': 'SPX6900 (Wormhole)',
#     'symbol': 'SPX'},
#    'quoteToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '1.4464',
#    'priceUsd': '1.44',
#    'txns': {'m5': {'buys': 0, 'sells': 8},
#     'h1': {'buys': 105, 'sells': 414},
#     'h6': {'buys': 2013, 'sells': 2085},
#     'h24': {'buys': 8344, 'sells': 7051}},
#    'volume': {'h24': 5946145.36,
#     'h6': 1446115.32,
#     'h1': 180407.82,
#     'm5': 6233.7},
#    'priceChange': {'m5': -0.12, 'h1': -2.9, 'h6': -0.53, 'h24': 6.64},
#    'liquidity': {'usd': 1134206.15, 'base': 507213, 'quote': 400533},
#    'fdv': 181459060,
#    'marketCap': 181459060,
#    'pairCreatedAt': 1728792488000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/J3NKxxXZcnNiMjKw9hYb2K4LUxgwB6t1FtPtQVsv3KFr.png?key=d66be8',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/J3NKxxXZcnNiMjKw9hYb2K4LUxgwB6t1FtPtQVsv3KFr/header.png?key=d66be8',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/J3NKxxXZcnNiMjKw9hYb2K4LUxgwB6t1FtPtQVsv3KFr?timestamp=1750018500000',
#     'websites': [{'label': 'Website', 'url': 'https://www.spx6900.com/'}],
#     'socials': [{'type': 'twitter', 'url': 'https://twitter.com/spx6900'},
#      {'type': 'telegram', 'url': 'https://t.me/SPX6900Portal'}]}},
#   {'chainId': 'solana',
#    'dexId': 'meteora',
#    'url': 'https://dexscreener.com/solana/9dirurpjnanzhn6ts5hglouhtjrt1jgspbxnycrfz2ad',
#    'pairAddress': '9DiruRpjnAnzhn6ts5HGLouHtJrT1JGsPbXNYCrFz2ad',
#    'labels': ['DLMM'],
#    'baseToken': {'address': 'FUAfBo2jgks6gB4Z4LfZkqSZgzNucisEHqnNebaRxM1P',
#     'name': 'Melania Meme',
#     'symbol': 'MELANIA'},
#    'quoteToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '0.2649',
#    'priceUsd': '0.2649',
#    'txns': {'m5': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 0, 'sells': 0},
#     'h6': {'buys': 4, 'sells': 0},
#     'h24': {'buys': 18, 'sells': 1}},
#    'volume': {'h24': 15205.18, 'h6': 2734.66, 'h1': 0, 'm5': 0},
#    'priceChange': {'h6': 3.06, 'h24': 1},
#    'liquidity': {'usd': 32072071.8, 'base': 88557352, 'quote': 8607677},
#    'fdv': 264962488,
#    'marketCap': 105698792,
#    'pairCreatedAt': 1737320909000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/FUAfBo2jgks6gB4Z4LfZkqSZgzNucisEHqnNebaRxM1P.png?key=3ca80b',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/FUAfBo2jgks6gB4Z4LfZkqSZgzNucisEHqnNebaRxM1P/header.png?key=3ca80b',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/FUAfBo2jgks6gB4Z4LfZkqSZgzNucisEHqnNebaRxM1P?timestamp=1750018500000',
#     'websites': [{'label': 'Website', 'url': 'https://melaniameme.com/'}],
#     'socials': [{'type': 'twitter',
#       'url': 'https://x.com/MELANIATRUMP/status/1881087523847593995'}]}},
#   {'chainId': 'solana',
#    'dexId': 'orca',
#    'url': 'https://dexscreener.com/solana/6nuivmsnjsi4afsmseiaezsav9n4n1zrd4jenuwnrvyb',
#    'pairAddress': '6NUiVmsNjsi4AfsMsEiaezsaV9N4N1ZrD4jEnuWNRvyb',
#    'labels': ['wp'],
#    'baseToken': {'address': '27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4',
#     'name': 'Jupiter Perps LP',
#     'symbol': 'JLP'},
#    'quoteToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '4.4369',
#    'priceUsd': '4.43',
#    'txns': {'m5': {'buys': 6, 'sells': 74},
#     'h1': {'buys': 595, 'sells': 751},
#     'h6': {'buys': 4682, 'sells': 4498},
#     'h24': {'buys': 12994, 'sells': 11542}},
#    'volume': {'h24': 16361587.1,
#     'h6': 7134795.54,
#     'h1': 983984.35,
#     'm5': 47515.04},
#    'priceChange': {'m5': -0.06, 'h1': -0.45, 'h6': 0.59, 'h24': 2.46},
#    'liquidity': {'usd': 8131853.67, 'base': 1287635, 'quote': 2418698},
#    'fdv': 1709833398,
#    'marketCap': 1709833398,
#    'pairCreatedAt': 1711347352000},
#   {'chainId': 'solana',
#    'dexId': 'raydium',
#    'url': 'https://dexscreener.com/solana/7dhrqbplfljzf9iwj1tsksfgv171fxn77jfvspjpngup',
#    'pairAddress': '7DHRQBPLFLjZf9iWJ1TSKSFgV171fXn77JfvSpjPNGuP',
#    'labels': ['CPMM'],
#    'baseToken': {'address': 'Ta1wrnVmwJ25RpE4KN7z4YNMvBhSKgi4U6uu9xEtime',
#     'name': "Kawz's minutes",
#     'symbol': 'Kawz'},
#    'quoteToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '13.6188',
#    'priceUsd': '13.61',
#    'txns': {'m5': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 13, 'sells': 7},
#     'h6': {'buys': 370, 'sells': 257},
#     'h24': {'buys': 388, 'sells': 292}},
#    'volume': {'h24': 184163.16, 'h6': 177166.91, 'h1': 5852.12, 'm5': 0},
#    'priceChange': {'h1': -3.19, 'h6': 74.93, 'h24': 84.33},
#    'liquidity': {'usd': 213143.78, 'base': 7825.3449, 'quote': 106571},
#    'fdv': 1361748,
#    'marketCap': 1361748,
#    'pairCreatedAt': 1740417535000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/Ta1wrnVmwJ25RpE4KN7z4YNMvBhSKgi4U6uu9xEtime.png?key=6b901a',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/Ta1wrnVmwJ25RpE4KN7z4YNMvBhSKgi4U6uu9xEtime/header.png?key=6b901a',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/Ta1wrnVmwJ25RpE4KN7z4YNMvBhSKgi4U6uu9xEtime?timestamp=1750018500000',
#     'websites': [{'label': 'Website', 'url': 'https://time.fun/kawz'}],
#     'socials': [{'type': 'twitter', 'url': 'https://x.com/kawz'}]}},
#   {'chainId': 'solana',
#    'dexId': 'raydium',
#    'url': 'https://dexscreener.com/solana/x4nd6lexnrj3ufecty8rsuo3qbktirsz4tqpus5sjrh',
#    'pairAddress': 'x4ND6LEXnrj3ufeCTY8RSuo3qbktirsz4tqPus5SjrH',
#    'labels': ['CLMM'],
#    'baseToken': {'address': 'boopkpWqe68MSxLqBGogs8ZbUDN4GXaLhFwNP7mpP1i',
#     'name': 'BOOP',
#     'symbol': 'BOOP'},
#    'quoteToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '0.04224',
#    'priceUsd': '0.04224',
#    'txns': {'m5': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 2, 'sells': 3},
#     'h6': {'buys': 37, 'sells': 41},
#     'h24': {'buys': 138, 'sells': 132}},
#    'volume': {'h24': 67268.39, 'h6': 16033.09, 'h1': 406.98, 'm5': 0},
#    'priceChange': {'h1': -0.15, 'h6': -0.7, 'h24': -0.34},
#    'liquidity': {'usd': 825692.33, 'base': 9344096, 'quote': 430969},
#    'fdv': 42243005,
#    'marketCap': 12692044,
#    'pairCreatedAt': 1746108268000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/boopkpWqe68MSxLqBGogs8ZbUDN4GXaLhFwNP7mpP1i.png?key=ac2426',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/boopkpWqe68MSxLqBGogs8ZbUDN4GXaLhFwNP7mpP1i/header.png?key=ac2426',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/boopkpWqe68MSxLqBGogs8ZbUDN4GXaLhFwNP7mpP1i?timestamp=1750018500000',
#     'websites': [{'label': 'Website', 'url': 'https://boop.fun/'}],
#     'socials': [{'type': 'twitter', 'url': 'https://x.com/boopdotfun'},
#      {'type': 'telegram', 'url': 'https://t.me/boopdotfun'}]}},
#   {'chainId': 'solana',
#    'dexId': 'meteora',
#    'url': 'https://dexscreener.com/solana/anrjzimfmlfh1lpmqqhu1eebxshrjpv7jeghh5kv4wro',
#    'pairAddress': 'ANrJZimFmLFH1LpMQqhU1eEbXSHrjPV7jegHH5KV4wro',
#    'labels': ['DLMM'],
#    'baseToken': {'address': '9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump',
#     'name': 'Fartcoin ',
#     'symbol': 'Fartcoin '},
#    'quoteToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '1.1947',
#    'priceUsd': '1.19',
#    'txns': {'m5': {'buys': 2, 'sells': 9},
#     'h1': {'buys': 227, 'sells': 329},
#     'h6': {'buys': 1791, 'sells': 1637},
#     'h24': {'buys': 5859, 'sells': 4804}},
#    'volume': {'h24': 6598357.43,
#     'h6': 2002410.37,
#     'h1': 316637.5,
#     'm5': 5958.24},
#    'priceChange': {'m5': -0.29, 'h1': -2.95, 'h6': -1.89, 'h24': 6.61},
#    'liquidity': {'usd': 928061.18, 'base': 609958, 'quote': 199333},
#    'fdv': 1194708766,
#    'marketCap': 1194706010,
#    'pairCreatedAt': 1740639283000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump.png?key=6a4a45',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump/header.png?key=6a4a45',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump?timestamp=1750018500000',
#     'websites': [{'label': 'Website',
#       'url': 'https://www.infinitebackrooms.com/dreams/conversation-1721540624-scenario-terminal-of-truths-txt'}],
#     'socials': [{'type': 'twitter', 'url': 'https://x.com/FartCoinOfSOL'}]}},
#   {'chainId': 'solana',
#    'dexId': 'meteora',
#    'url': 'https://dexscreener.com/solana/g8p7nqwmbqab8f6jb9lbrburxtrk7lykpg6ws9vkfbrh',
#    'pairAddress': 'G8P7nqwMBqAb8F6jb9LBrBURXTRk7LykpG6wS9VKfbRH',
#    'labels': ['DYN'],
#    'baseToken': {'address': 'GTMiS5AFCRuYZdonZoWRyzmusoMFhTFtPgKc5YZJtime',
#     'name': 'ZackMorris',
#     'symbol': 'ZackMorris'},
#    'quoteToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '3.8292',
#    'priceUsd': '3.82',
#    'txns': {'m5': {'buys': 4, 'sells': 0},
#     'h1': {'buys': 45, 'sells': 24},
#     'h6': {'buys': 177, 'sells': 96},
#     'h24': {'buys': 285, 'sells': 163}},
#    'volume': {'h24': 73998.95, 'h6': 50860.93, 'h1': 11011.93, 'm5': 171.35},
#    'priceChange': {'m5': 0.79, 'h1': -8.59, 'h6': 52.73, 'h24': 108},
#    'liquidity': {'usd': 87170.71, 'base': 11474, 'quote': 43233},
#    'fdv': 380754,
#    'marketCap': 380754,
#    'pairCreatedAt': 1747591927000},
#   {'chainId': 'solana',
#    'dexId': 'raydium',
#    'url': 'https://dexscreener.com/solana/5wgyajm1xtly3qrlhgsx4ypwsso3jrjesbu1vivuerzk',
#    'pairAddress': '5WGYajM1xtLy3QrLHGSX4YPwsso3jrjEsbU1VivUErzk',
#    'baseToken': {'address': 'HhJpBhRRn4g56VsyLuT8DL5Bv31HkXqsrahTTUCZeZg4',
#     'name': 'Myro',
#     'symbol': '$MYRO'},
#    'quoteToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '0.01941',
#    'priceUsd': '0.01941',
#    'txns': {'m5': {'buys': 1, 'sells': 0},
#     'h1': {'buys': 2, 'sells': 29},
#     'h6': {'buys': 187, 'sells': 200},
#     'h24': {'buys': 581, 'sells': 578}},
#    'volume': {'h24': 117080.87, 'h6': 43596.13, 'h1': 4179.05, 'm5': 11.29},
#    'priceChange': {'m5': 0.48, 'h1': -1.05, 'h6': 0.61, 'h24': 2.22},
#    'liquidity': {'usd': 1507249.44, 'base': 38866057, 'quote': 752687},
#    'fdv': 19413772,
#    'marketCap': 19413772,
#    'pairCreatedAt': 1699554931000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/HhJpBhRRn4g56VsyLuT8DL5Bv31HkXqsrahTTUCZeZg4.png?key=2a995b',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/HhJpBhRRn4g56VsyLuT8DL5Bv31HkXqsrahTTUCZeZg4/header.png?key=2a995b',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/HhJpBhRRn4g56VsyLuT8DL5Bv31HkXqsrahTTUCZeZg4?timestamp=1750018500000',
#     'websites': [{'label': 'Website', 'url': 'http://myrothedog.com'}],
#     'socials': [{'type': 'twitter', 'url': 'https://twitter.com/myrosol'},
#      {'type': 'telegram', 'url': 'https://t.me/myrosol'}]}},
#   {'chainId': 'solana',
#    'dexId': 'meteora',
#    'url': 'https://dexscreener.com/solana/ea6erp59cjxl248yjd8dbedj8dcifrdurha7wlndkxod',
#    'pairAddress': 'Ea6erp59cjxL248Yjd8dbedJ8dcifrdurHa7WLnDkxod',
#    'labels': ['DYN'],
#    'baseToken': {'address': 'EKSKQP7iz5s9L8db6s9T2u9o7cczTCWEUscsXHxatime',
#     'name': 'degenping',
#     'symbol': 'degenping'},
#    'quoteToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '3.3173',
#    'priceUsd': '3.31',
#    'txns': {'m5': {'buys': 0, 'sells': 2},
#     'h1': {'buys': 7, 'sells': 7},
#     'h6': {'buys': 33, 'sells': 22},
#     'h24': {'buys': 97, 'sells': 56}},
#    'volume': {'h24': 26578.36, 'h6': 12512.2, 'h1': 4643.56, 'm5': 2728.14},
#    'priceChange': {'m5': -13.36, 'h1': -16.52, 'h6': 8.26, 'h24': 15.38},
#    'liquidity': {'usd': 81092.67, 'base': 12124, 'quote': 40872},
#    'fdv': 331733,
#    'marketCap': 331733,
#    'pairCreatedAt': 1749593454000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/EKSKQP7iz5s9L8db6s9T2u9o7cczTCWEUscsXHxatime.png?key=6988e6',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/EKSKQP7iz5s9L8db6s9T2u9o7cczTCWEUscsXHxatime/header.png?key=6988e6',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/EKSKQP7iz5s9L8db6s9T2u9o7cczTCWEUscsXHxatime?timestamp=1750018500000',
#     'websites': [{'label': 'Website', 'url': 'https://time.fun/degenping'}],
#     'socials': [{'type': 'twitter', 'url': 'https://x.com/DegenPing'},
#      {'type': 'discord', 'url': 'https://discord.gg/timedotfun'}]}},
#   {'chainId': 'solana',
#    'dexId': 'raydium',
#    'url': 'https://dexscreener.com/solana/cexpzumwadu6ddzfgqmkxm8ufu1zvkgwk3tdvhwmifr9',
#    'pairAddress': 'CExPZUmwAdu6dDZFGQmkxM8UFu1zVkGwk3tDVHWMifR9',
#    'labels': ['CPMM'],
#    'baseToken': {'address': 'HAs8hvTB8ZH6dBG26KQGik4fxitNYi41jnYd49bvtime',
#     'name': "Ansem's minutes",
#     'symbol': 'Ansem'},
#    'quoteToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '13.7718',
#    'priceUsd': '13.77',
#    'txns': {'m5': {'buys': 0, 'sells': 0},
#     'h1': {'buys': 2, 'sells': 8},
#     'h6': {'buys': 72, 'sells': 67},
#     'h24': {'buys': 80, 'sells': 72}},
#    'volume': {'h24': 68597.16, 'h6': 65105.26, 'h1': 5219.79, 'm5': 0},
#    'priceChange': {'h1': 3.75, 'h6': 51.37, 'h24': 48.35},
#    'liquidity': {'usd': 166482.89, 'base': 6044.3347, 'quote': 83241},
#    'fdv': 1377181,
#    'marketCap': 1377181,
#    'pairCreatedAt': 1742963438000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/HAs8hvTB8ZH6dBG26KQGik4fxitNYi41jnYd49bvtime.png?key=bafd55',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/HAs8hvTB8ZH6dBG26KQGik4fxitNYi41jnYd49bvtime/header.png?key=bafd55',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/HAs8hvTB8ZH6dBG26KQGik4fxitNYi41jnYd49bvtime?timestamp=1750018500000',
#     'websites': [{'label': 'Website', 'url': 'https://time.fun/ansem'}],
#     'socials': [{'type': 'twitter', 'url': 'https://x.com/blknoiz06'},
#      {'type': 'discord', 'url': 'https://discord.gg/timedotfun'}]}},
#   {'chainId': 'solana',
#    'dexId': 'orca',
#    'url': 'https://dexscreener.com/solana/j5jzvt22u1mt6de4gkbheststjbfys7a6af5jzu9ihkc',
#    'pairAddress': 'J5jzvT22u1Mt6de4gkBhEsTSTjBfYS7A6aF5jzu9ihkC',
#    'labels': ['wp'],
#    'baseToken': {'address': '9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump',
#     'name': 'Fartcoin ',
#     'symbol': 'Fartcoin '},
#    'quoteToken': {'address': 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v',
#     'name': 'USD Coin',
#     'symbol': 'USDC'},
#    'priceNative': '1.1956',
#    'priceUsd': '1.19',
#    'txns': {'m5': {'buys': 8, 'sells': 43},
#     'h1': {'buys': 455, 'sells': 569},
#     'h6': {'buys': 2716, 'sells': 3267},
#     'h24': {'buys': 8586, 'sells': 9542}},
#    'volume': {'h24': 4488661.13,
#     'h6': 1554753.74,
#     'h1': 313217.47,
#     'm5': 10311.29},
#    'priceChange': {'m5': -0.22, 'h1': -2.83, 'h6': -1.77, 'h24': 6.59},
#    'liquidity': {'usd': 231284.07, 'base': 121210, 'quote': 86357},
#    'fdv': 1195656476,
#    'marketCap': 1195653717,
#    'pairCreatedAt': 1747349952000,
#    'info': {'imageUrl': 'https://dd.dexscreener.com/ds-data/tokens/solana/9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump.png?key=6a4a45',
#     'header': 'https://dd.dexscreener.com/ds-data/tokens/solana/9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump/header.png?key=6a4a45',
#     'openGraph': 'https://cdn.dexscreener.com/token-images/og/solana/9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump?timestamp=1750018500000',
#     'websites': [{'label': 'Website',
#       'url': 'https://www.infinitebackrooms.com/dreams/conversation-1721540624-scenario-terminal-of-truths-txt'}],
#     'socials': [{'type': 'twitter', 'url': 'https://x.com/FartCoinOfSOL'}]}}]}

# %%
# Extract mint addresses with FDV < 1 billion or no FDV data
# Using existing fdv_df from the previous cells

# Filter for tokens with FDV < 1 billion or NaN (no FDV data)
low_fdv_threshold = 1e9  # 1 billion
low_fdv_tokens = fdv_df[(fdv_df['fdv'] < low_fdv_threshold) | (fdv_df['fdv'].isna())]

# Get the original data for tokens not in fdv_df (those that couldn't be processed)
processed_mints = set(fdv_df['mint_address'])
missing_mints = [addr for addr in df['mint_address'] if addr not in processed_mints]

# Create a dataframe for tokens not in fdv_df
missing_df = df[df['mint_address'].isin(missing_mints)][['mint_address', 'usd_volume']]

print(f"Found {len(low_fdv_tokens)} tokens with FDV < {low_fdv_threshold} or no FDV data")
print(f"Found {len(missing_mints)} tokens not processed in fdv_df")
print(f"Total: {len(low_fdv_tokens) + len(missing_mints)} tokens")

# Combine both sets of tokens (low FDV and missing)
combined_low_fdv = pd.DataFrame({'mint_address': low_fdv_tokens['mint_address'].tolist() + missing_df['mint_address'].tolist()})

# Save to CSV
combined_low_fdv.to_csv('solana_low_fdv_mints.csv', index=False)
print(f"Saved {len(combined_low_fdv)} mint addresses to solana_low_fdv_mints.csv")

# Show first 20 mint addresses
combined_low_fdv.head(20)

# %%
# Save to CSV and analyze results
low_fdv_df.to_csv('solana_low_fdv_mints.csv', index=False)
print(f"Results saved to solana_low_fdv_mints.csv")

# Show distribution by status
status_counts = low_fdv_df['fdv_status'].value_counts()
print("\nDistribution by status:")
print(status_counts)

# Show mint addresses only (for easy copying)
print("\nFirst 20 mint addresses:")
print(low_fdv_df['mint_address'].head(20).to_list())

# %%
import json
import pandas as pd

def extract_fdv_info(json_file_path):
    """
    Extract FDV (fully diluted valuation) information from dexscreener data.
    Only uses pairs where the mint_address is the baseToken, and deduplicates results.
    
    Args:
        json_file_path: Path to the solana_dexscreener_info.json file
        
    Returns:
        DataFrame with mint_address, name, symbol, fdv, and other relevant info
    """
    # Load the JSON data
    with open(json_file_path, 'r') as f:
        data = json.load(f)
    
    # List to store extracted information
    extracted_info = []
    
    # Process each mint address
    for entry in data:
        mint_address = entry['mint_address']
        usd_volume = entry['usd_volume']
        
        try:
            # Parse the dexscreener data
            dex_data = json.loads(entry['dexscreener_data'])
            
            # Skip if no pairs data
            if not dex_data or 'pairs' not in dex_data or not dex_data['pairs']:
                continue
                
            # Find pairs where this mint_address is the baseToken
            valid_pairs = []
            for pair in dex_data['pairs']:
                if pair.get('baseToken', {}).get('address') == mint_address:
                    valid_pairs.append(pair)
            
            # Skip if no valid pairs found
            if not valid_pairs:
                continue
                
            # Get the pair with the highest liquidity (most reliable data)
            best_pair = max(valid_pairs, key=lambda p: p.get('liquidity', {}).get('usd', 0) or 0)
            
            # Extract information
            info = {
                'mint_address': mint_address,
                'name': best_pair.get('baseToken', {}).get('name'),
                'symbol': best_pair.get('baseToken', {}).get('symbol'),
                #'price_usd': best_pair.get('priceUsd'),
                'fdv': best_pair.get('fdv'),
                #'market_cap': best_pair.get('marketCap'),
                #'liquidity_usd': best_pair.get('liquidity', {}).get('usd'),
                #'volume_24h': best_pair.get('volume', {}).get('h24'),
                #'price_change_24h': best_pair.get('priceChange', {}).get('h24'),
                #'usd_volume': usd_volume,
                #'pair_address': best_pair.get('pairAddress'),
                #'dex_id': best_pair.get('dexId'),
                #'url': best_pair.get('url')
            }
            
            extracted_info.append(info)
            
        except Exception as e:
            print(f"Error processing {mint_address}: {e}")
    
    # Convert to DataFrame and deduplicate
    df = pd.DataFrame(extracted_info)
    df = df.drop_duplicates(subset=['mint_address'])
    
    # Convert numeric columns
    numeric_cols = ['fdv']
    for col in numeric_cols:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')
    
    return df


fdv_df = extract_fdv_info('solana_dexscreener_info.json')
fdv_df.to_csv('solana_fdv_info.csv', index=False)

# %%
fdv_df
# Out:
#                                       mint_address                    name  \
# 0      So11111111111111111111111111111111111111112             Wrapped SOL
# 1     EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v                USD Coin
# 2     3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh  Wrapped BTC (Wormhole)
# 3     Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB                    USDT
# 4     6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN          OFFICIAL TRUMP
# ...                                            ...                     ...
# 2768  4XQvdipJBdrb5hUgUrbZPPFmp6BCav41n55dc7KDYW3m                 ENGLAND
# 2769  6AKyiCnqtYw67mMDJsFxBQgHzqUgPUXiQaXNkRz2pump        Father of Crypto
# 2770  7NfRbZBV9U5jfoqqGjDyJrJqsfiPCAJDL3Yf2xMsN1sg                FARTBABY
# 2771  DNyxufTEwqNCgGruJ4W2ue6u1RTFcH61H4sa42LGpump                 bullish
# 2772  8aJuQEkQstCrSUXVGpmgaTqgSG7cW8FmVaudu8UBem6A                   PUCCA
#
#         symbol           fdv
# 0          SOL           NaN
# 1         USDC  8.612518e+09
# 2         WBTC  4.057594e+08
# 3         USDT  2.040750e+09
# 4        TRUMP  9.931412e+09
# ...        ...           ...
# 2768       ENG  4.537900e+04
# 2769   Satoshi  3.364800e+04
# 2770  FARTBABY  1.806800e+04
# 2771   bullish  2.333100e+04
# 2772     PUCCA  1.679400e+04
#
# [2773 rows x 4 columns]

# %%
# Extract mint addresses with FDV < 1 billion or no FDV data
# Using existing fdv_df from the previous cells

# Filter for tokens with FDV < 1 billion or NaN (no FDV data)
low_fdv_threshold = 1e9  # 1 billion
low_fdv_tokens = fdv_df[(fdv_df['fdv'] < low_fdv_threshold)]

# Get the original data for tokens not in fdv_df (those that couldn't be processed)
processed_mints = set(fdv_df['mint_address'])
missing_mints = [addr for addr in df['mint_address'] if addr not in processed_mints]

# Create a dataframe for tokens not in fdv_df
missing_df = df[df['mint_address'].isin(missing_mints)][['mint_address', 'usd_volume']]

print(f"Found {len(low_fdv_tokens)} tokens with FDV < {low_fdv_threshold} or no FDV data")
print(f"Found {len(missing_mints)} tokens not processed in fdv_df")
print(f"Total: {len(low_fdv_tokens) + len(missing_mints)} tokens")

# Combine both sets of tokens (low FDV and missing)
combined_low_fdv = pd.DataFrame({'mint_address': low_fdv_tokens['mint_address'].tolist() + missing_df['mint_address'].tolist()})

# Save to CSV
combined_low_fdv.to_csv('solana_low_fdv_mints.csv', index=False)
print(f"Saved {len(combined_low_fdv)} mint addresses to solana_low_fdv_mints.csv")

# Show first 20 mint addresses
combined_low_fdv.head(20)
# Out:
# Found 2748 tokens with FDV < 1000000000.0 or no FDV data
# Found 3188 tokens not processed in fdv_df
# Total: 5936 tokens
# Saved 5936 mint addresses to solana_low_fdv_mints.csv
#                                     mint_address
# 0   3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh
# 1   EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm
# 2   7GCihgDB8fe6KNjn2MYtkzZcRjQy3t9GHdC8uHYmW2hr
# 3    mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So
# 4    v62Jv9pwMTREWV9f6TetZfMafV254vo99p7HSF25BPr
# 5   7vfCXTUXx5WJV5JADk17DUJ4ksgau7utNKj4b963voxs
# 6   FUAfBo2jgks6gB4Z4LfZkqSZgzNucisEHqnNebaRxM1P
# 7   HeLp6NuQkmYB4pYWo2zYs22mESHXPQYzXbB8n4V98jwC
# 8   7BgBvyjrZX1YKz4oh9mjb8ZScatkkwb8DzFx7LoiVkM3
# 9    cbbtcf3aa214zXHbiAZQwf4122FBYbraNdFqgw4iMij
# 10   jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v
# 11   bSo13r4TkiE4KumL71LsHTPpL2euBYLFx6h9HP3piy1
# 12  2b1kV6DkPAnxd5ixfnxCpjxmKwqjjaYmCZfHsFu24GXo
# 13  2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv
# 14  CzLSujWBLFsSjncfkh59rUFqvafWcY5tzedWJSuypump
# 15   ukHH6c7mMyiWCf1b9pnWe25TSpkDDt3H5pQZgZ74J82
# 16  61V8vBaqAGMpgDQi4JcAwo1dmBGHsyhzodcPqnEVpump
# 17   MEW1gQWJ3nEXg2qgERiKu7FAFj79PHvQVREQUzScPP5
# 18  Df6yfrKC8kZE3KNkrHERKzAetSxbrWeniQfyJY4Jpump
# 19  6AJcP7wuLwmRYLBNbi825wgguaPsWzPBEHcHndpRpump

# %%
# Save to CSV and analyze results
combined_low_fdv.to_csv('solana_low_fdv_mints.csv', index=False)
print(f"Results saved to solana_low_fdv_mints.csv")
# Out:
# Results saved to solana_low_fdv_mints.csv
